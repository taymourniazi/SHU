# %%
#Read Data
dataset=read.csv('cow.csv')

# %%
#know how of dataset
names(dataset)
# Out:
# [1] "ID"     "weight" "time"

# %%
#Applying Linear Regression(here y comes first then x)
regressor=lm(dataset$weight~dataset$time)

# %%
#brief of linear regression model
summary(regressor)
# Out:
# Call:
# lm(formula = dataset$weight ~ dataset$time)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -31.601  -6.703   1.711   8.019  27.062
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  81.14951    6.86117   11.83 9.51e-11 ***
# dataset$time  0.42311    0.01421   29.78  < 2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 13.99 on 21 degrees of freedom
# Multiple R-squared:  0.9769,	Adjusted R-squared:  0.9758
# F-statistic: 886.9 on 1 and 21 DF,  p-value: < 2.2e-16

# %%
#finding intercept and slope
coef(regressor)
# Out:
#  (Intercept) dataset$time
#   81.1495123    0.4231136

# %%
#Applying Linear Regression
plot(dataset$time, dataset$weight, main = 'Scatter Plot', xlab = 'Time', ylab = 'Weight' )
# Out:
# Plot with title "Scatter Plot"

# %%
#plotting regression line
plot(dataset$time, dataset$weight, main = 'Scatter Plot', xlab = 'Time', ylab = 'Weight' )
abline(regressor, col='blue', lwd=2)
# Out:
# Plot with title "Scatter Plot"
