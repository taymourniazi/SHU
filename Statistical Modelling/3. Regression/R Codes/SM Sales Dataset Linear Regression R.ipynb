# %%
#Read Data
dataset=read.csv('sales.csv')

# %%
#Applying Linear Regression(here y comes first then x)
regressor=lm(dataset$credit~dataset$income)

# %%
#brief of linear regression model
summary(regressor)
# Out:
# Call:
# lm(formula = dataset$credit ~ dataset$income)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.1998 -0.8648 -0.1819  0.9040  3.1624
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)     3.43633    0.67500   5.091 2.16e-05 ***
# dataset$income  0.19558    0.02029   9.639 2.15e-10 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 1.495 on 28 degrees of freedom
# Multiple R-squared:  0.7684,	Adjusted R-squared:  0.7601
# F-statistic: 92.91 on 1 and 28 DF,  p-value: 2.154e-10

# %%
#Applying Linear Regression
plot(dataset$income, dataset$credit, main = 'Scatter Plot for Sales dataset',
     xlab = 'Income', ylab = 'Credit' )
# Out:
# Plot with title "Scatter Plot for Sales dataset"

# %%
#plotting regression line
plot(dataset$income, dataset$credit, main = 'Scatter Plot for Sales dataset',
     xlab = 'Income', ylab = 'Credit' )
abline(regressor, col='blue', lwd=2)
# Out:
# Plot with title "Scatter Plot for Sales dataset"
